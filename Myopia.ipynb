# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Read in the .csv file
df = pd.read_csv("Resources/myopia.csv")
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
# Drop the MYOPIC column
labels = df["MYOPIC"]
df = df.drop(columns=["MYOPIC"])
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0        0    10         34      1      1
# 1        1     7         12      1      1
# 2        0    10         14      0      0
# 3        0     4         37      0      1
# 4        0     4          4      1      0

# %%
# Scale the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
# Perform dimensionality reduction with PCA
pca = PCA(n_components=0.9)
myopia_pca = pca.fit_transform(scaled_data)

# Convert PCA to DataFrame
pca_df = pd.DataFrame(myopia_pca)
pca_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1 -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2 -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3  0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4 -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
#
#           7         8         9
# 0 -1.922997  0.026753  0.178144
# 1  0.285332  0.689683 -0.557031
# 2 -0.030817 -0.431499  0.013336
# 3 -1.717109 -1.230785 -0.703400
# 4 -1.301787  0.279007  0.631183

# %%
# Further reduce dimensions using t-SNE
tsne = TSNE(learning_rate=35)
tsne_features = tsne.fit_transform(pca_df)
tsne_features.shape
# Out:
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# (618, 2)

# %%
# Visualise the t-SNE output
pca_df['x'] = tsne_features[:,0]
pca_df['y'] = tsne_features[:,1]
plt.scatter(pca_df['x'], pca_df['y'], c=labels)
plt.show()

# %% [markdown]
# There appears to be several distinct clusters.

# %%
# Finding the best value for k
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pca_df)
    inertia.append(km.inertia_)

# Plot the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
elbow_df = pd.DataFrame(elbow_data)

plt.plot(elbow_df["k"], elbow_df["inertia"])
plt.xticks(k)
plt.title("Elbow Curve to determine number of clusters in dataset")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()
# Out:
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   "KMeans is known to have a memory leak on Windows "
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# ...

# %%
# Plot the data with 5 clusters
model = KMeans(n_clusters=5, random_state=0)
model.fit(pca_df)
predictions = model.predict(pca_df)
pca_df["class"] = model.labels_
plt.scatter(pca_df["x"], pca_df["y"], c=pca_df["class"])
plt.show()
# Out:
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# c:\Users\frank\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %% [markdown]
# From my analysis of the data, and as seen in the above figure, my recommendation is to group the patients into 5 distinct clusters.
